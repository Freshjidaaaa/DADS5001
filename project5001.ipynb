# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print( f"Python {sys.version}\nPandas {pd.__version__}\nNumPy {np.__version__}" )
# Out:
# Python 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]
# Pandas 1.4.4
# NumPy 1.22.4

# %% [markdown]
# ### เตรียมข้อมูล เอาไฟล์ raw_titles.csv เข้า

# %%
df_titles = pd.read_csv('raw_titles.csv')  
df_titles
#รายละเอียดหนัง
# Out:
#       index         id                                title   type  \
# 0         0   ts300399  Five Came Back: The Reference Films   SHOW
# 1         1    tm84618                          Taxi Driver  MOVIE
# 2         2   tm127384      Monty Python and the Holy Grail  MOVIE
# 3         3    tm70993                        Life of Brian  MOVIE
# 4         4   tm190788                         The Exorcist  MOVIE
# ...     ...        ...                                  ...    ...
# 5801   5801  tm1014599                            Fine Wine  MOVIE
# 5802   5802  tm1108171                       Edis Starlight  MOVIE
# 5803   5803  tm1045018                                Clash  MOVIE
# 5804   5804  tm1098060                       Shadow Parties  MOVIE
# 5805   5805   ts271048   Mighty Little Bheem: Kite Festival   SHOW
#
#       release_year age_certification  runtime  \
# 0             1945             TV-MA       48
# 1             1976                 R      113
# 2             1975                PG       91
# 3             1979                 R       94
# 4             1973                 R      133
# ...            ...               ...      ...
# 5801          2021               NaN      100
# 5802          2021               NaN       74
# 5803          2021               NaN       88
# 5804          2021               NaN      116
# 5805          2021               NaN        0
#
#                                  genres production_countries  seasons  \
# 0                     ['documentation']               ['US']      1.0
# 1                    ['crime', 'drama']               ['US']      NaN
# 2                 ['comedy', 'fantasy']               ['GB']      NaN
# 3                            ['comedy']               ['GB']      NaN
# 4                            ['horror']               ['US']      NaN
# ...                                 ...                  ...      ...
# 5801               ['romance', 'drama']               ['NG']      NaN
# 5802         ['music', 'documentation']                   []      NaN
# 5803                ['family', 'drama']         ['NG', 'CA']      NaN
# 5804             ['action', 'thriller']                   []      NaN
# 5805  ['family', 'comedy', 'animation']                   []      1.0
#
#          imdb_id  imdb_score  imdb_votes
# 0            NaN         NaN         NaN
# 1      tt0075314         8.3    795222.0
# 2      tt0071853         8.2    530877.0
# 3      tt0079470         8.0    392419.0
# 4      tt0070047         8.1    391942.0
# ...          ...         ...         ...
# 5801  tt13857480         6.9        39.0
# 5802         NaN         NaN         NaN
# 5803  tt14620732         6.5        32.0
# 5804  tt10168094         6.2         9.0
# 5805  tt13711094         8.8        16.0
#
# [5806 rows x 13 columns]

# %%
#cleandata
df_titles.isna().sum()
# Out:
# index                      0
# id                         0
# title                      1
# type                       0
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# dtype: int64

# %%
#drop NaN ในคอลัมน์ imdb_score, imdb_id และ imdb_votes
df_titles=df_titles.dropna(subset=['imdb_score','imdb_id','imdb_votes'])
df_titles.head()
# Out:
#    index        id                            title   type  release_year  \
# 1      1   tm84618                      Taxi Driver  MOVIE          1976
# 2      2  tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 3      3   tm70993                    Life of Brian  MOVIE          1979
# 4      4  tm190788                     The Exorcist  MOVIE          1973
# 5      5   ts22164     Monty Python's Flying Circus   SHOW          1969
#
#   age_certification  runtime                  genres production_countries  \
# 1                 R      113      ['crime', 'drama']               ['US']
# 2                PG       91   ['comedy', 'fantasy']               ['GB']
# 3                 R       94              ['comedy']               ['GB']
# 4                 R      133              ['horror']               ['US']
# 5             TV-14       30  ['comedy', 'european']               ['GB']
#
#    seasons    imdb_id  imdb_score  imdb_votes
# 1      NaN  tt0075314         8.3    795222.0
# 2      NaN  tt0071853         8.2    530877.0
# 3      NaN  tt0079470         8.0    392419.0
# 4      NaN  tt0070047         8.1    391942.0
# 5      4.0  tt0063929         8.8     72895.0

# %%
df_titles.isna().sum()
# Out:
# index                      0
# id                         0
# title                      0
# type                       0
# release_year               0
# age_certification       2278
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3391
# imdb_id                    0
# imdb_score                 0
# imdb_votes                 0
# dtype: int64

# %%
df_titles.loc[df_titles['imdb_score'].isna()]
# Out:
# Empty DataFrame
# Columns: [index, id, title, type, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes]
# Index: []

# %% [markdown]
# ## df_show

# %%
#ความนิยมของซีรีส์
#แบ่งข้อมูลออกมาเฉพาะที่เป็นซีรีส์
df_show = df_titles[df_titles['type']=='SHOW']
df_show.head()
# Out:
#     index       id                             title  type  release_year  \
# 5       5  ts22164      Monty Python's Flying Circus  SHOW          1969
# 29     29  ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47     47  ts20681                          Seinfeld  SHOW          1989
# 55     55  ts22082                      Knight Rider  SHOW          1982
# 57     57  ts21715                  Thomas & Friends  SHOW          1984
#
#    age_certification  runtime  \
# 5              TV-14       30
# 29             TV-MA       43
# 47             TV-PG       24
# 55             TV-PG       51
# 57              TV-Y       10
#
#                                                genres production_countries  \
# 5                              ['comedy', 'european']               ['GB']
# 29                                         ['comedy']                   []
# 47                                         ['comedy']               ['US']
# 55              ['action', 'scifi', 'crime', 'drama']               ['US']
# 57  ['family', 'comedy', 'music', 'action', 'anima...               ['GB']
#
#     seasons    imdb_id  imdb_score  imdb_votes
# 5       4.0  tt0063929         8.8     72895.0
# 29      1.0  tt0202477         8.1      2144.0
# 47      9.0  tt0098904         8.9    302700.0
# 55      4.0  tt0083437         6.9     33760.0
# 57     24.0  tt0086815         6.5      4948.0

# %%
df_show.isna().sum()
# Out:
# index                     0
# id                        0
# title                     0
# type                      0
# release_year              0
# age_certification       206
# runtime                   0
# genres                    0
# production_countries      0
# seasons                   0
# imdb_id                   0
# imdb_score                0
# imdb_votes                0
# dtype: int64

# %%
#เลือกข้อมูลมาแค่แถว ที่ imdb_score มากกว่าเท่ากับ 8
df_show_8=df_show[df_show['imdb_score']>=8]
df_show_8.head()
# Out:
#      index       id                             title  type  release_year  \
# 5        5  ts22164      Monty Python's Flying Circus  SHOW          1969
# 29      29  ts45948  Monty Python's Fliegender Zirkus  SHOW          1972
# 47      47  ts20681                          Seinfeld  SHOW          1989
# 106    106  ts22176                     Stargate SG-1  SHOW          1997
# 110    110  ts20339                         One Piece  SHOW          1999
#
#     age_certification  runtime  \
# 5               TV-14       30
# 29              TV-MA       43
# 47              TV-PG       24
# 106             TV-PG       44
# 110             TV-14       23
#
#                                                 genres production_countries  \
# 5                               ['comedy', 'european']               ['GB']
# 29                                          ['comedy']                   []
# 47                                          ['comedy']               ['US']
# 106                       ['scifi', 'drama', 'action']         ['US', 'CA']
# 110  ['action', 'comedy', 'animation', 'drama', 'fa...               ['JP']
#
#      seasons    imdb_id  imdb_score  imdb_votes
# 5        4.0  tt0063929         8.8     72895.0
# 29       1.0  tt0202477         8.1      2144.0
# 47       9.0  tt0098904         8.9    302700.0
# 106     10.0  tt0118480         8.4     90196.0
# 110     21.0  tt0388629         8.8    112586.0

# %%
df_show_8=df_show_8.sort_values(by='imdb_votes',ascending=True)
df_show_8
# Out:
#       index        id                title  type  release_year  \
# 5680   5680  ts288861            Let's Eat  SHOW          2021
# 2181   2181   ts82268                GHOUL  SHOW          2018
# 2927   2927  ts265844             #ABtalks  SHOW          2018
# 4913   4913   ts94677  Worst Roommate Ever  SHOW          2022
# 1488   1488  ts144323  Unnatural Selection  SHOW          2015
# ...     ...       ...                  ...   ...           ...
# 940     940       ts6       House of Cards  SHOW          2013
# 704     704     ts278         Black Mirror  SHOW          2011
# 244     244       ts9     The Walking Dead  SHOW          2010
# 1219   1219   ts38796      Stranger Things  SHOW          2016
# 243     243       ts4         Breaking Bad  SHOW          2008
#
#      age_certification  runtime  \
# 5680             TV-14       60
# 2181             TV-MA       46
# 2927             TV-PG       68
# 4913             TV-MA       47
# 1488             TV-MA       35
# ...                ...      ...
# 940              TV-MA       52
# 704              TV-MA       59
# 244              TV-MA       46
# 1219             TV-14       52
# 243              TV-MA       48
#
#                                                  genres production_countries  \
# 5680                                ['drama', 'comedy']               ['TH']
# 2181            ['scifi', 'drama', 'fantasy', 'horror']               ['IN']
# 2927                                                 []                   []
# 4913    ['crime', 'documentation', 'drama', 'thriller']               ['US']
# 1488             ['reality', 'documentation', 'comedy']               ['US']
# ...                                                 ...                  ...
# 940                                           ['drama']               ['US']
# 704          ['scifi', 'thriller', 'drama', 'european']               ['GB']
# 244   ['action', 'drama', 'scifi', 'thriller', 'horr...               ['US']
# 1219  ['scifi', 'drama', 'fantasy', 'horror', 'thril...               ['US']
# 243                      ['drama', 'thriller', 'crime']               ['US']
#
#       seasons     imdb_id  imdb_score  imdb_votes
# 5680      1.0  tt15978704         8.2         5.0
# 2181      2.0   tt5909930         8.0         6.0
# 2927      1.0  tt12635254         9.6         7.0
# 4913      1.0   tt8323702         8.1         8.0
# 1488      1.0  tt11063952         8.1        12.0
# ...       ...         ...         ...         ...
# 940       6.0   tt1856010         8.7    494092.0
# 704       5.0   tt2085059         8.8    515577.0
# 244      11.0   tt1520211         8.2    945125.0
# 1219      5.0   tt4575572         8.7    989090.0
# 243       5.0   tt0903747         9.5   1727694.0
#
# [350 rows x 13 columns]

# %%
mean_vote_8 = df_show_8['imdb_votes'].mean()
mean_vote_8
# Out:
# 57670.102857142854

# %%
df_votes_8_lessmean=df_show_8[df_show_8['imdb_votes']<mean_vote_8]
df_votes_8_lessmean.head()
# Out:
#       index        id                title  type  release_year  \
# 5680   5680  ts288861            Let's Eat  SHOW          2021
# 2181   2181   ts82268                GHOUL  SHOW          2018
# 2927   2927  ts265844             #ABtalks  SHOW          2018
# 4913   4913   ts94677  Worst Roommate Ever  SHOW          2022
# 1488   1488  ts144323  Unnatural Selection  SHOW          2015
#
#      age_certification  runtime  \
# 5680             TV-14       60
# 2181             TV-MA       46
# 2927             TV-PG       68
# 4913             TV-MA       47
# 1488             TV-MA       35
#
#                                                genres production_countries  \
# 5680                              ['drama', 'comedy']               ['TH']
# 2181          ['scifi', 'drama', 'fantasy', 'horror']               ['IN']
# 2927                                               []                   []
# 4913  ['crime', 'documentation', 'drama', 'thriller']               ['US']
# 1488           ['reality', 'documentation', 'comedy']               ['US']
#
#       seasons     imdb_id  imdb_score  imdb_votes
# 5680      1.0  tt15978704         8.2         5.0
# 2181      2.0   tt5909930         8.0         6.0
# 2927      1.0  tt12635254         9.6         7.0
# 4913      1.0   tt8323702         8.1         8.0
# 1488      1.0  tt11063952         8.1        12.0

# %%
df_votes_8_lessmean.sort_values(by='imdb_score',ascending=False)
# Out:
#       index        id                title  type  release_year  \
# 2927   2927  ts265844             #ABtalks  SHOW          2018
# 656     656  ts160526             Khawatir  SHOW          2005
# 3320   3320   ts85398           Our Planet  SHOW          2019
# 2057   2057   ts78298            My Mister  SHOW          2018
# 1422   1422   ts37660           Reply 1988  SHOW          2015
# ...     ...       ...                  ...   ...           ...
# 782     782   ts34737     La Reina del Sur  SHOW          2011
# 2125   2125   ts76417          Tabula Rasa  SHOW          2017
# 3821   3821  ts226617  The Innocence Files  SHOW          2020
# 2169   2169   ts88234      Man Like Mobeen  SHOW          2017
# 5062   5062  ts253813               Glória  SHOW          2021
#
#      age_certification  runtime                                       genres  \
# 2927             TV-PG       68                                           []
# 656              TV-14       20                                  ['reality']
# 3320              TV-G       50                            ['documentation']
# 2057             TV-14       79                          ['drama', 'family']
# 1422             TV-14       95     ['comedy', 'drama', 'family', 'romance']
# ...                ...      ...                                          ...
# 782              TV-MA       42     ['drama', 'action', 'crime', 'thriller']
# 2125             TV-MA       52  ['drama', 'horror', 'thriller', 'european']
# 3821             TV-MA       64          ['documentation', 'crime', 'drama']
# 2169             TV-MA       22                                   ['comedy']
# 5062             TV-MA       44             ['drama', 'history', 'thriller']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 2927                   []      1.0  tt12635254         9.6         7.0
# 656                    []     11.0   tt3062514         9.6      3046.0
# 3320               ['GB']      1.0   tt9253866         9.3     41386.0
# 2057               ['KR']      1.0   tt7923710         9.2      5481.0
# 1422               ['KR']      1.0   tt5182866         9.2      6557.0
# ...                   ...      ...         ...         ...         ...
# 782                ['MX']      2.0   tt1704637         8.0      2445.0
# 2125               ['BE']      1.0   tt5197860         8.0     10161.0
# 3821               ['US']      1.0  tt11958922         8.0      2622.0
# 2169               ['GB']      3.0   tt7639280         8.0      2664.0
# 5062               ['PT']      1.0  tt13064634         8.0      3941.0
#
# [272 rows x 13 columns]

# %%
df_votes_8_lessmean.sort_values(by='imdb_votes',ascending=False)
# Out:
#       index        id                                             title  type  \
# 1870   1870   ts58133                                           Manhunt  SHOW
# 1258   1258   ts42120                                         Travelers  SHOW
# 1867   1867   ts55982                                    Anne with an E  SHOW
# 3258   3258  ts223210  Don't F**k with Cats: Hunting an Internet Killer  SHOW
# 1222   1222   ts35251                                 Grace and Frankie  SHOW
# ...     ...       ...                                               ...   ...
# 1488   1488  ts144323                               Unnatural Selection  SHOW
# 4913   4913   ts94677                               Worst Roommate Ever  SHOW
# 2927   2927  ts265844                                          #ABtalks  SHOW
# 2181   2181   ts82268                                             GHOUL  SHOW
# 5680   5680  ts288861                                         Let's Eat  SHOW
#
#       release_year age_certification  runtime  \
# 1870          2017             TV-14       43
# 1258          2016             TV-MA       45
# 1867          2017              TV-G       46
# 3258          2019             TV-MA       62
# 1222          2015             TV-MA       30
# ...            ...               ...      ...
# 1488          2015             TV-MA       35
# 4913          2022             TV-MA       47
# 2927          2018             TV-PG       68
# 2181          2018             TV-MA       46
# 5680          2021             TV-14       60
#
#                                                genres production_countries  \
# 1870  ['documentation', 'crime', 'thriller', 'drama']               ['US']
# 1258          ['scifi', 'drama', 'thriller', 'crime']               ['CA']
# 1867                              ['drama', 'family']               ['CA']
# 3258                       ['crime', 'documentation']         ['US', 'GB']
# 1222                              ['comedy', 'drama']               ['US']
# ...                                               ...                  ...
# 1488           ['reality', 'documentation', 'comedy']               ['US']
# 4913  ['crime', 'documentation', 'drama', 'thriller']               ['US']
# 2927                                               []                   []
# 2181          ['scifi', 'drama', 'fantasy', 'horror']               ['IN']
# 5680                              ['drama', 'comedy']               ['TH']
#
#       seasons     imdb_id  imdb_score  imdb_votes
# 1870      2.0   tt5618256         8.1     57459.0
# 1258      3.0   tt5651844         8.0     54566.0
# 1867      3.0   tt5421602         8.7     51001.0
# 3258      1.0  tt11318602         8.0     50250.0
# 1222      7.0   tt3609352         8.2     48435.0
# ...       ...         ...         ...         ...
# 1488      1.0  tt11063952         8.1        12.0
# 4913      1.0   tt8323702         8.1         8.0
# 2927      1.0  tt12635254         9.6         7.0
# 2181      2.0   tt5909930         8.0         6.0
# 5680      1.0  tt15978704         8.2         5.0
#
# [272 rows x 13 columns]

# %%
df_votes_8_moremean=df_show_8[df_show_8['imdb_votes']>=mean_vote_8]
df_votes_8_moremean
# Out:
#       index       id                                 title  type  \
# 1883   1883  ts56261                           Castlevania  SHOW
# 113     113  ts20927            Star Trek: Deep Space Nine  SHOW
# 288     288  ts17942                      Chappelle's Show  SHOW
# 331     331  ts12787  Code Geass: Lelouch of the Rebellion  SHOW
# 263     263  ts20604                   Friday Night Lights  SHOW
# ...     ...      ...                                   ...   ...
# 940     940      ts6                        House of Cards  SHOW
# 704     704    ts278                          Black Mirror  SHOW
# 244     244      ts9                      The Walking Dead  SHOW
# 1219   1219  ts38796                       Stranger Things  SHOW
# 243     243      ts4                          Breaking Bad  SHOW
#
#       release_year age_certification  runtime  \
# 1883          2017             TV-MA       26
# 113           1993             TV-PG       47
# 288           2003             TV-14       21
# 331           2006             TV-14       24
# 263           2006             TV-14       43
# ...            ...               ...      ...
# 940           2013             TV-MA       52
# 704           2011             TV-MA       59
# 244           2010             TV-MA       46
# 1219          2016             TV-14       52
# 243           2008             TV-MA       48
#
#                                                  genres production_countries  \
# 1883  ['scifi', 'drama', 'fantasy', 'horror', 'anima...               ['US']
# 113                        ['scifi', 'action', 'drama']               ['US']
# 288                                 ['comedy', 'music']               ['US']
# 331   ['scifi', 'animation', 'action', 'drama', 'thr...               ['JP']
# 263                                  ['drama', 'sport']               ['US']
# ...                                                 ...                  ...
# 940                                           ['drama']               ['US']
# 704          ['scifi', 'thriller', 'drama', 'european']               ['GB']
# 244   ['action', 'drama', 'scifi', 'thriller', 'horr...               ['US']
# 1219  ['scifi', 'drama', 'fantasy', 'horror', 'thril...               ['US']
# 243                      ['drama', 'thriller', 'crime']               ['US']
#
#       seasons    imdb_id  imdb_score  imdb_votes
# 1883      4.0  tt6517102         8.3     61114.0
# 113       7.0  tt0106145         8.1     61145.0
# 288       3.0  tt0353049         8.8     62140.0
# 331       3.0  tt0994314         8.7     62367.0
# 263       5.0  tt0758745         8.7     64449.0
# ...       ...        ...         ...         ...
# 940       6.0  tt1856010         8.7    494092.0
# 704       5.0  tt2085059         8.8    515577.0
# 244      11.0  tt1520211         8.2    945125.0
# 1219      5.0  tt4575572         8.7    989090.0
# 243       5.0  tt0903747         9.5   1727694.0
#
# [78 rows x 13 columns]

# %%
df_votes_8_moremean.sort_values(by='imdb_score',ascending=False)
# Out:
#       index        id                       title  type  release_year  \
# 243     243       ts4                Breaking Bad  SHOW          2008
# 259     259    ts3371  Avatar: The Last Airbender  SHOW          2005
# 3827   3827   ts90621                Kota Factory  SHOW          2019
# 3196   3196   ts81120              The Last Dance  SHOW          2020
# 4847   4847  ts222333                      Arcane  SHOW          2021
# ...     ...       ...                         ...   ...           ...
# 950     950   ts20280                  Marco Polo  SHOW          2014
# 3194   3194   ts82914                  Dead to Me  SHOW          2019
# 3289   3289  ts225522                  Unorthodox  SHOW          2020
# 3185   3185   ts76645        The Umbrella Academy  SHOW          2019
# 918     918    ts1639               The Blacklist  SHOW          2013
#
#      age_certification  runtime  \
# 243              TV-MA       48
# 259              TV-Y7       24
# 3827             TV-MA       42
# 3196             TV-MA       50
# 4847             TV-14       41
# ...                ...      ...
# 950              TV-MA       55
# 3194             TV-MA       31
# 3289             TV-MA       54
# 3185             TV-14       52
# 918              TV-14       43
#
#                                                  genres production_countries  \
# 243                      ['drama', 'thriller', 'crime']               ['US']
# 259   ['scifi', 'family', 'fantasy', 'animation', 'a...               ['US']
# 3827                                ['drama', 'comedy']               ['IN']
# 3196              ['documentation', 'history', 'sport']               ['US']
# 4847  ['action', 'scifi', 'drama', 'fantasy', 'anima...               ['US']
# ...                                                 ...                  ...
# 950     ['action', 'drama', 'history', 'documentation']               ['US']
# 3194                       ['drama', 'crime', 'comedy']               ['US']
# 3289                                          ['drama']               ['DE']
# 3185  ['comedy', 'drama', 'fantasy', 'scifi', 'action']               ['US']
# 918                      ['drama', 'crime', 'thriller']               ['US']
#
#       seasons     imdb_id  imdb_score  imdb_votes
# 243       5.0   tt0903747         9.5   1727694.0
# 259       3.0   tt0417299         9.3    297336.0
# 3827      2.0   tt9432978         9.3     66985.0
# 3196      1.0   tt8420184         9.1    108321.0
# 4847      1.0  tt11126994         9.1    175412.0
# ...       ...         ...         ...         ...
# 950       2.0   tt2189461         8.0     71229.0
# 3194      2.0   tt9889712         8.0     73110.0
# 3289      1.0   tt7607544         8.0     74118.0
# 3185      3.0   tt1312171         8.0    202522.0
# 918       9.0   tt2741602         8.0    238138.0
#
# [78 rows x 13 columns]

# %%
df_votes_8_moremean.sort_values(by='imdb_votes',ascending=False).head(10)
# Out:
#       index        id             title  type  release_year age_certification  \
# 243     243       ts4      Breaking Bad  SHOW          2008             TV-MA
# 1219   1219   ts38796   Stranger Things  SHOW          2016             TV-14
# 244     244       ts9  The Walking Dead  SHOW          2010             TV-MA
# 704     704     ts278      Black Mirror  SHOW          2011             TV-MA
# 940     940       ts6    House of Cards  SHOW          2013             TV-MA
# 916     916   ts20110    Peaky Blinders  SHOW          2013             TV-MA
# 3186   3186   ts57327       The Witcher  SHOW          2019             TV-MA
# 1844   1844   ts56768       Money Heist  SHOW          2017             TV-MA
# 253     253   ts21465      Supernatural  SHOW          2005             TV-14
# 4863   4863  ts220305        Squid Game  SHOW          2021             TV-MA
#
#       runtime                                             genres  \
# 243        48                     ['drama', 'thriller', 'crime']
# 1219       52  ['scifi', 'drama', 'fantasy', 'horror', 'thril...
# 244        46  ['action', 'drama', 'scifi', 'thriller', 'horr...
# 704        59         ['scifi', 'thriller', 'drama', 'european']
# 940        52                                          ['drama']
# 916        58                     ['drama', 'crime', 'european']
# 3186       58  ['scifi', 'action', 'drama', 'fantasy', 'horror']
# 1844       50  ['crime', 'drama', 'thriller', 'action', 'euro...
# 253        45  ['scifi', 'thriller', 'drama', 'fantasy', 'hor...
# 4863       54                    ['action', 'drama', 'thriller']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 243                ['US']      5.0   tt0903747         9.5   1727694.0
# 1219               ['US']      5.0   tt4575572         8.7    989090.0
# 244                ['US']     11.0   tt1520211         8.2    945125.0
# 704                ['GB']      5.0   tt2085059         8.8    515577.0
# 940                ['US']      6.0   tt1856010         8.7    494092.0
# 916                ['GB']      6.0   tt2442560         8.8    485506.0
# 3186               ['US']      2.0   tt5180504         8.2    465949.0
# 1844               ['ES']      5.0   tt6468322         8.3    450797.0
# 253                ['US']     15.0   tt0460681         8.5    428639.0
# 4863               ['KR']      2.0  tt10919420         8.0    416738.0

# %%
df_show_8.genres = df_show_8.genres.str[1:-1].str.split(',')

# %%
show_genres = pd.Series(sum([item for item in df_show_8.genres], [])).str.replace(' ', '').value_counts().to_frame('count')
show_genres.reset_index()
# Out:
#               index  count
# 0           'drama'    224
# 1          'comedy'    147
# 2        'thriller'     74
# 3          'action'     70
# 4       'animation'     69
# 5           'crime'     65
# 6           'scifi'     64
# 7         'fantasy'     64
# 8         'romance'     62
# 9   'documentation'     61
# 10         'family'     42
# 11       'european'     29
# 12         'horror'     26
# 13        'history'     25
# 14        'reality'     19
# 15            'war'     15
# 16          'sport'     14
# 17          'music'      9
# 18        'western'      2
# 19                       1

# %%
show_genres = show_genres.reset_index()
show_genres
# Out:
#               index  count
# 0           'drama'    224
# 1          'comedy'    147
# 2        'thriller'     74
# 3          'action'     70
# 4       'animation'     69
# 5           'crime'     65
# 6           'scifi'     64
# 7         'fantasy'     64
# 8         'romance'     62
# 9   'documentation'     61
# 10         'family'     42
# 11       'european'     29
# 12         'horror'     26
# 13        'history'     25
# 14        'reality'     19
# 15            'war'     15
# 16          'sport'     14
# 17          'music'      9
# 18        'western'      2
# 19                       1

# %%
df_show_8=df_show[df_show['imdb_score']>=8]
df_show_8.loc[ df_show_8['genres'].str.contains('drama', case=False)].sort_values(by='imdb_votes',ascending=False).head(1)
# Out:
#      index   id         title  type  release_year age_certification  runtime  \
# 243    243  ts4  Breaking Bad  SHOW          2008             TV-MA       48
#
#                              genres production_countries  seasons    imdb_id  \
# 243  ['drama', 'thriller', 'crime']               ['US']      5.0  tt0903747
#
#      imdb_score  imdb_votes
# 243         9.5   1727694.0

# %%
df_show_8.loc[ df_show_8['genres'].str.contains('crime', case=False)].sort_values(by='imdb_votes',ascending=False).head(1)
# Out:
#      index   id         title  type  release_year age_certification  runtime  \
# 243    243  ts4  Breaking Bad  SHOW          2008             TV-MA       48
#
#                              genres production_countries  seasons    imdb_id  \
# 243  ['drama', 'thriller', 'crime']               ['US']      5.0  tt0903747
#
#      imdb_score  imdb_votes
# 243         9.5   1727694.0

# %%
df_show_8.loc[ df_show_8['genres'].str.contains('thriller', case=False)].sort_values(by='imdb_votes',ascending=False).head(1)
# Out:
#      index   id         title  type  release_year age_certification  runtime  \
# 243    243  ts4  Breaking Bad  SHOW          2008             TV-MA       48
#
#                              genres production_countries  seasons    imdb_id  \
# 243  ['drama', 'thriller', 'crime']               ['US']      5.0  tt0903747
#
#      imdb_score  imdb_votes
# 243         9.5   1727694.0

# %%
df_show_8.loc[ df_show_8['genres'].str.contains('comedy', case=False)].sort_values(by='imdb_votes',ascending=False).head(1)
# Out:
#       index   id             title  type  release_year age_certification  \
# 1217   1217  ts8  Better Call Saul  SHOW          2015             TV-MA
#
#       runtime                        genres production_countries  seasons  \
# 1217       49  ['comedy', 'drama', 'crime']               ['US']      6.0
#
#         imdb_id  imdb_score  imdb_votes
# 1217  tt3032476         8.8    404920.0

# %%
df_show_8.loc[ df_show_8['genres'].str.contains('scifi', case=False)].sort_values(by='imdb_votes',ascending=False).head(1)
# Out:
#       index       id            title  type  release_year age_certification  \
# 1219   1219  ts38796  Stranger Things  SHOW          2016             TV-14
#
#       runtime                                             genres  \
# 1219       52  ['scifi', 'drama', 'fantasy', 'horror', 'thril...
#
#      production_countries  seasons    imdb_id  imdb_score  imdb_votes
# 1219               ['US']      5.0  tt4575572         8.7    989090.0

# %%
df_show_8.loc[ df_show_8['genres'].str.contains('', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index                   350
# id                      350
# title                   350
# type                    350
# release_year            350
# age_certification       313
# runtime                 350
# genres                  350
# production_countries    350
# seasons                 350
# imdb_id                 350
# imdb_score              350
# imdb_votes              350
# dtype: int64

# %%
#show_genres
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=show_genres['index'],
          width=show_genres['count'])
plt.xlabel("Number of Genres")
plt.ylabel("Genres of Series")
# Out:
# Text(0, 0.5, 'Genres of Series')

# %%
plt.figure(figsize=(15,5), dpi=150)
ax = plt.gca()
sns.histplot(data=df_show_8, x='imdb_score', bins=20, alpha=0.6, ax=ax )
# Out:
# <AxesSubplot:xlabel='imdb_score', ylabel='Count'>

# %%
# df_show_8 imdb_votes>=400000
df_show_top_vote = df_show_8[df_show_8['imdb_votes']>=400000]
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=df_show_top_vote['title'],
          width=df_show_top_vote['imdb_votes'] )
plt.xlabel("Number of imdb_votes")
plt.ylabel("Title of Series")
# Out:
# Text(0, 0.5, 'Title of Series')

# %%
# df_votes_8_lessmean imdb_votes>=40000
df_show_top_vote = df_votes_8_lessmean[df_votes_8_lessmean['imdb_votes']>=40000]
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=df_show_top_vote['title'],
          width=df_show_top_vote['imdb_votes'] )
plt.xlabel("Number of imdb_votes")
plt.ylabel("Title of Series")
# Out:
# Text(0, 0.5, 'Title of Series')

# %%
# df_votes_8_moremean imdb_votes>=400000
df_show_top10_vote = df_votes_8_moremean[df_votes_8_moremean['imdb_votes']>=400000]
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=df_show_top10_vote['title'],
          width=df_show_top10_vote['imdb_votes'] )
plt.xlabel("Number of imdb_votes") # Add x-labels
plt.ylabel("Title of Series")
# Out:
# Text(0, 0.5, 'Title of Series')

# %% [markdown]
# ## df_movie

# %%
df_movie = df_titles.loc[df_titles['type'] == 'MOVIE']
df_movie
# Out:
#       index         id                            title   type  release_year  \
# 1         1    tm84618                      Taxi Driver  MOVIE          1976
# 2         2   tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 3         3    tm70993                    Life of Brian  MOVIE          1979
# 4         4   tm190788                     The Exorcist  MOVIE          1973
# 6         6    tm14873                      Dirty Harry  MOVIE          1971
# ...     ...        ...                              ...    ...           ...
# 5798   5798  tm1004011                    Time to Dance  MOVIE          2021
# 5800   5800  tm1040816      Momshies! Your Soul is Mine  MOVIE          2021
# 5801   5801  tm1014599                        Fine Wine  MOVIE          2021
# 5803   5803  tm1045018                            Clash  MOVIE          2021
# 5804   5804  tm1098060                   Shadow Parties  MOVIE          2021
#
#      age_certification  runtime                           genres  \
# 1                    R      113               ['crime', 'drama']
# 2                   PG       91            ['comedy', 'fantasy']
# 3                    R       94                       ['comedy']
# 4                    R      133                       ['horror']
# 6                    R      102  ['thriller', 'crime', 'action']
# ...                ...      ...                              ...
# 5798               NaN      107             ['drama', 'romance']
# 5800               NaN      108                       ['comedy']
# 5801               NaN      100             ['romance', 'drama']
# 5803               NaN       88              ['family', 'drama']
# 5804               NaN      116           ['action', 'thriller']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes
# 1                  ['US']      NaN   tt0075314         8.3    795222.0
# 2                  ['GB']      NaN   tt0071853         8.2    530877.0
# 3                  ['GB']      NaN   tt0079470         8.0    392419.0
# 4                  ['US']      NaN   tt0070047         8.1    391942.0
# 6                  ['US']      NaN   tt0066999         7.7    153463.0
# ...                   ...      ...         ...         ...         ...
# 5798               ['IN']      NaN   tt8622232         2.2       950.0
# 5800               ['PH']      NaN  tt14412240         5.8        26.0
# 5801               ['NG']      NaN  tt13857480         6.9        39.0
# 5803         ['NG', 'CA']      NaN  tt14620732         6.5        32.0
# 5804                   []      NaN  tt10168094         6.2         9.0
#
# [3391 rows x 13 columns]

# %%
df_movie = df_movie.drop(columns=['seasons'])

# %%
df_movie.isna().sum()
# Out:
# index                      0
# id                         0
# title                      0
# type                       0
# release_year               0
# age_certification       2072
# runtime                    0
# genres                     0
# production_countries       0
# imdb_id                    0
# imdb_score                 0
# imdb_votes                 0
# dtype: int64

# %%
#เลือกข้อมูลมาแค่แถว ที่ imdb_score มากกว่าเท่ากับ 8
df_movie_8 = df_movie[df_movie['imdb_score'] >= 8]
df_movie_8.head()
# Out:
#     index        id                            title   type  release_year  \
# 1       1   tm84618                      Taxi Driver  MOVIE          1976
# 2       2  tm127384  Monty Python and the Holy Grail  MOVIE          1975
# 3       3   tm70993                    Life of Brian  MOVIE          1979
# 4       4  tm190788                     The Exorcist  MOVIE          1973
# 13     13   tm69997   Richard Pryor: Live in Concert  MOVIE          1979
#
#    age_certification  runtime                       genres  \
# 1                  R      113           ['crime', 'drama']
# 2                 PG       91        ['comedy', 'fantasy']
# 3                  R       94                   ['comedy']
# 4                  R      133                   ['horror']
# 13                 R       78  ['comedy', 'documentation']
#
#    production_countries    imdb_id  imdb_score  imdb_votes
# 1                ['US']  tt0075314         8.3    795222.0
# 2                ['GB']  tt0071853         8.2    530877.0
# 3                ['GB']  tt0079470         8.0    392419.0
# 4                ['US']  tt0070047         8.1    391942.0
# 13               ['US']  tt0079807         8.1      5141.0

# %%
df_movie_8=df_movie_8.sort_values(by='imdb_votes',ascending=True)
df_movie_8
# Out:
#       index        id                                 title   type  \
# 4430   4430  tm835414                                Sitara  MOVIE
# 876     876  tm166740  Chhota Bheem & Krishna in Mayanagari  MOVIE
# 1211   1211  tm529733   Chhota Bheem and the ShiNobi Secret  MOVIE
# 1208   1208  tm528044            Chhota Bheem Neeli Pahaadi  MOVIE
# 1202   1202  tm250247     Chhota Bheem & Krishna vs Zimbara  MOVIE
# ...     ...       ...                                   ...    ...
# 1         1   tm84618                           Taxi Driver  MOVIE
# 111     111   tm57554                   Saving Private Ryan  MOVIE
# 706     706   tm41792                      Django Unchained  MOVIE
# 108     108  tm122434                          Forrest Gump  MOVIE
# 260     260   tm92641                             Inception  MOVIE
#
#       release_year age_certification  runtime  \
# 4430          2019               NaN      128
# 876           2011                 G       66
# 1211          2013                 G       63
# 1208          2013                 G       63
# 1202          2013                 G       64
# ...            ...               ...      ...
# 1             1976                 R      113
# 111           1998                 R      169
# 706           2012                 R      165
# 108           1994             PG-13      142
# 260           2010             PG-13      148
#
#                                         genres production_countries  \
# 4430                    ['drama', 'animation']               ['IN']
# 876         ['animation', 'action', 'fantasy']               ['IN']
# 1211                             ['animation']               ['IN']
# 1208                             ['animation']                   []
# 1202                             ['animation']                   []
# ...                                        ...                  ...
# 1                           ['crime', 'drama']               ['US']
# 111                           ['drama', 'war']               ['US']
# 706                       ['western', 'drama']               ['US']
# 108             ['drama', 'romance', 'comedy']               ['US']
# 260   ['scifi', 'music', 'thriller', 'action']         ['GB', 'US']
#
#          imdb_id  imdb_score  imdb_votes
# 4430   tt7654668         8.0         5.0
# 876   tt16235600         9.0         5.0
# 1211   tt6417830         8.6         6.0
# 1208   tt6442694         8.5         9.0
# 1202   tt6417984         8.6        13.0
# ...          ...         ...         ...
# 1      tt0075314         8.3    795222.0
# 111    tt0120815         8.6   1346020.0
# 706    tt1853728         8.4   1472668.0
# 108    tt0109830         8.8   1994599.0
# 260    tt1375666         8.8   2268288.0
#
# [155 rows x 12 columns]

# %%
mean_movie_8 = df_movie_8['imdb_votes'].mean()
mean_movie_8
# Out:
# 134331.7548387097

# %%
df_movie_votes_8_lessmean=df_movie_8[df_movie_8['imdb_votes']<mean_vote_8]
df_movie_votes_8_lessmean.head()
# Out:
#       index        id                                 title   type  \
# 4430   4430  tm835414                                Sitara  MOVIE
# 876     876  tm166740  Chhota Bheem & Krishna in Mayanagari  MOVIE
# 1211   1211  tm529733   Chhota Bheem and the ShiNobi Secret  MOVIE
# 1208   1208  tm528044            Chhota Bheem Neeli Pahaadi  MOVIE
# 1202   1202  tm250247     Chhota Bheem & Krishna vs Zimbara  MOVIE
#
#       release_year age_certification  runtime  \
# 4430          2019               NaN      128
# 876           2011                 G       66
# 1211          2013                 G       63
# 1208          2013                 G       63
# 1202          2013                 G       64
#
#                                   genres production_countries     imdb_id  \
# 4430              ['drama', 'animation']               ['IN']   tt7654668
# 876   ['animation', 'action', 'fantasy']               ['IN']  tt16235600
# 1211                       ['animation']               ['IN']   tt6417830
# 1208                       ['animation']                   []   tt6442694
# 1202                       ['animation']                   []   tt6417984
#
#       imdb_score  imdb_votes
# 4430         8.0         5.0
# 876          9.0         5.0
# 1211         8.6         6.0
# 1208         8.5         9.0
# 1202         8.6        13.0

# %%
df_movie_votes_8_lessmean.sort_values(by='imdb_score',ascending=False)
# Out:
#       index         id                                      title   type  \
# 25       25    tm76557                             No Longer Kids  MOVIE
# 2814   2814   tm432327                          C/o Kancharapalem  MOVIE
# 3352   3352   tm853783   David Attenborough: A Life on Our Planet  MOVIE
# 876     876   tm166740       Chhota Bheem & Krishna in Mayanagari  MOVIE
# 4473   4473   tm907872                        Sky Tour: The Movie  MOVIE
# ...     ...        ...                                        ...    ...
# 776     776   tm182586                                   Silenced  MOVIE
# 1019   1019   tm171965  Mike Birbiglia: My Girlfriend's Boyfriend  MOVIE
# 2339   2339   tm443993               Take the Ball, Pass the Ball  MOVIE
# 5653   5653  tm1039168                               Cinema Bandi  MOVIE
# 4430   4430   tm835414                                     Sitara  MOVIE
#
#       release_year age_certification  runtime  \
# 25            1979               NaN      235
# 2814          2018                PG      152
# 3352          2020                PG       83
# 876           2011                 G       66
# 4473          2020               NaN       94
# ...            ...               ...      ...
# 776           2011               NaN      125
# 1019          2013               NaN       75
# 2339          2018               NaN      107
# 5653          2021               NaN       98
# 4430          2019               NaN      128
#
#                                                genres production_countries  \
# 25                                ['comedy', 'drama']               ['EG']
# 2814                                        ['drama']               ['IN']
# 3352                                ['documentation']               ['GB']
# 876                ['animation', 'action', 'fantasy']               ['IN']
# 4473                       ['documentation', 'music']                   []
# ...                                               ...                  ...
# 776                                         ['drama']               ['KR']
# 1019  ['drama', 'documentation', 'comedy', 'romance']               ['US']
# 2339           ['documentation', 'sport', 'european']               ['ES']
# 5653                              ['comedy', 'drama']               ['IN']
# 4430                           ['drama', 'animation']               ['IN']
#
#          imdb_id  imdb_score  imdb_votes
# 25     tt8312792         9.0       943.0
# 2814   tt7391996         9.0      6562.0
# 3352  tt11989890         9.0     31180.0
# 876   tt16235600         9.0         5.0
# 4473  tt12486200         8.8      1036.0
# ...          ...         ...         ...
# 776    tt2070649         8.0     15889.0
# 1019   tt2937390         8.0      3284.0
# 2339   tt9135854         8.0      3064.0
# 5653  tt14558738         8.0      2416.0
# 4430   tt7654668         8.0         5.0
#
# [113 rows x 12 columns]

# %%
df_movie_votes_8_lessmean.sort_values(by='imdb_votes',ascending=False).head(10)
# Out:
#       index         id                                           title   type  \
# 834     834    tm47171                                 OMG: Oh My God!  MOVIE
# 1107   1107   tm175812                                      Special 26  MOVIE
# 1058   1058   tm148910                                          Haider  MOVIE
# 156     156   tm190835  Neon Genesis Evangelion: The End of Evangelion  MOVIE
# 3215   3215   tm863808                              My Octopus Teacher  MOVIE
# 3816   3816   tm812998                           Miracle in Cell No. 7  MOVIE
# 607     607   tm103732                                           Udaan  MOVIE
# 4944   4944  tm1038686                              Bo Burnham: Inside  MOVIE
# 534     534    tm51493                                       Vizontele  MOVIE
# 844     844    tm35700                                Paan Singh Tomar  MOVIE
#
#       release_year age_certification  runtime  \
# 834           2012                 G      125
# 1107          2013               NaN      144
# 1058          2014             PG-13      150
# 156           1997               NaN       87
# 3215          2020               NaN       84
# 3816          2019               NaN      132
# 607           2010                 R      138
# 4944          2021                 R       87
# 534           2001               NaN      110
# 844           2012                PG      135
#
#                                                  genres production_countries  \
# 834                      ['fantasy', 'drama', 'comedy']               ['IN']
# 1107                     ['thriller', 'crime', 'drama']               ['IN']
# 1058           ['drama', 'action', 'crime', 'thriller']               ['IN']
# 156   ['scifi', 'action', 'drama', 'fantasy', 'anima...               ['JP']
# 3215                                  ['documentation']         ['ZA', 'GB']
# 3816                                          ['drama']               ['TR']
# 607                                           ['drama']               ['IN']
# 4944            ['comedy', 'drama', 'music', 'reality']               ['US']
# 534                                 ['comedy', 'drama']               ['TR']
# 844   ['drama', 'sport', 'thriller', 'action', 'crime']               ['IN']
#
#          imdb_id  imdb_score  imdb_votes
# 834    tt2283748         8.1     57449.0
# 1107   tt2377938         8.0     55489.0
# 1058   tt3390572         8.1     54001.0
# 156    tt0169858         8.0     51938.0
# 3215  tt12888462         8.1     51232.0
# 3816  tt10431500         8.2     46939.0
# 607    tt1639426         8.1     44556.0
# 4944  tt14545352         8.7     44074.0
# 534    tt0270053         8.0     36291.0
# 844    tt1620933         8.2     35888.0

# %%
df_movie_votes_8_moremean = df_movie_8[df_movie_8['imdb_votes']>=mean_vote_8]
df_movie_votes_8_moremean.head()
# Out:
#       index        id                      title   type  release_year  \
# 553     553   tm82718                   G.O.R.A.  MOVIE          2004
# 1073   1073  tm156811                      Queen  MOVIE          2014
# 484     484   tm61056             Dil Chahta Hai  MOVIE          2001
# 1276   1276  tm233425  A Silent Voice: The Movie  MOVIE          2016
# 791     791  tm182125   Zindagi Na Milegi Dobara  MOVIE          2011
#
#      age_certification  runtime                                       genres  \
# 553              PG-13      127                          ['scifi', 'comedy']
# 1073             PG-13      146                          ['drama', 'comedy']
# 484                  G      183               ['drama', 'comedy', 'romance']
# 1276             PG-13      130  ['romance', 'animation', 'drama', 'family']
# 791                 PG      166                          ['comedy', 'drama']
#
#      production_countries    imdb_id  imdb_score  imdb_votes
# 553                ['TR']  tt0384116         8.0     61797.0
# 1073               ['IN']  tt3322420         8.2     64805.0
# 484                ['IN']  tt0292490         8.1     71167.0
# 1276               ['JP']  tt5323662         8.1     75132.0
# 791                ['IN']  tt1562872         8.1     75801.0

# %%
df_movie_votes_8_moremean.count()
# Out:
# index                   42
# id                      42
# title                   42
# type                    42
# release_year            42
# age_certification       40
# runtime                 42
# genres                  42
# production_countries    42
# imdb_id                 42
# imdb_score              42
# imdb_votes              42
# dtype: int64

# %%
df_movie_votes_8_moremean.sort_values(by='imdb_score',ascending=False).head(10)
# Out:
#       index        id                        title   type  release_year  \
# 260     260   tm92641                    Inception  MOVIE          2010
# 108     108  tm122434                 Forrest Gump  MOVIE          1994
# 111     111   tm57554          Saving Private Ryan  MOVIE          1998
# 1375   1375  tm245671                       Dangal  MOVIE          2016
# 368     368  tm142564                     3 Idiots  MOVIE          2009
# 706     706   tm41792             Django Unchained  MOVIE          2012
# 1         1   tm84618                  Taxi Driver  MOVIE          1976
# 52       52   tm22327            Full Metal Jacket  MOVIE          1987
# 414     414   tm83786          Like Stars on Earth  MOVIE          2007
# 49       49  tm180542  Once Upon a Time in America  MOVIE          1984
#
#      age_certification  runtime                                    genres  \
# 260              PG-13      148  ['scifi', 'music', 'thriller', 'action']
# 108              PG-13      142            ['drama', 'romance', 'comedy']
# 111                  R      169                          ['drama', 'war']
# 1375                PG      161              ['action', 'drama', 'sport']
# 368              PG-13      170                       ['comedy', 'drama']
# 706                  R      165                      ['western', 'drama']
# 1                    R      113                        ['crime', 'drama']
# 52                   R      116                          ['drama', 'war']
# 414                 PG      165                       ['drama', 'family']
# 49                   R      229            ['drama', 'crime', 'european']
#
#      production_countries    imdb_id  imdb_score  imdb_votes
# 260          ['GB', 'US']  tt1375666         8.8   2268288.0
# 108                ['US']  tt0109830         8.8   1994599.0
# 111                ['US']  tt0120815         8.6   1346020.0
# 1375               ['IN']  tt5074352         8.4    180247.0
# 368                ['IN']  tt1187043         8.4    385782.0
# 706                ['US']  tt1853728         8.4   1472668.0
# 1                  ['US']  tt0075314         8.3    795222.0
# 52           ['GB', 'US']  tt0093058         8.3    723306.0
# 414                ['IN']  tt0986264         8.3    188234.0
# 49           ['US', 'IT']  tt0087843         8.3    342335.0

# %%
df_movie_votes_8_moremean.sort_values(by='imdb_votes',ascending=False).head(10)
# Out:
#      index        id                     title   type  release_year  \
# 260    260   tm92641                 Inception  MOVIE          2010
# 108    108  tm122434              Forrest Gump  MOVIE          1994
# 706    706   tm41792          Django Unchained  MOVIE          2012
# 111    111   tm57554       Saving Private Ryan  MOVIE          1998
# 1        1   tm84618               Taxi Driver  MOVIE          1976
# 927    927  tm140877        The Imitation Game  MOVIE          2014
# 52      52   tm22327         Full Metal Jacket  MOVIE          1987
# 262    262   tm87484  How to Train Your Dragon  MOVIE          2010
# 264    264   tm39030             Casino Royale  MOVIE          2006
# 282    282   tm79442      The Bourne Ultimatum  MOVIE          2007
#
#     age_certification  runtime  \
# 260             PG-13      148
# 108             PG-13      142
# 706                 R      165
# 111                 R      169
# 1                   R      113
# 927             PG-13      113
# 52                  R      116
# 262                PG       98
# 264               NaN      139
# 282             PG-13      115
#
#                                                 genres  \
# 260           ['scifi', 'music', 'thriller', 'action']
# 108                     ['drama', 'romance', 'comedy']
# 706                               ['western', 'drama']
# 111                                   ['drama', 'war']
# 1                                   ['crime', 'drama']
# 927                       ['thriller', 'drama', 'war']
# 52                                    ['drama', 'war']
# 262  ['fantasy', 'animation', 'action', 'comedy', '...
# 264                 ['thriller', 'action', 'european']
# 282                             ['thriller', 'action']
#
#                production_countries    imdb_id  imdb_score  imdb_votes
# 260                    ['GB', 'US']  tt1375666         8.8   2268288.0
# 108                          ['US']  tt0109830         8.8   1994599.0
# 706                          ['US']  tt1853728         8.4   1472668.0
# 111                          ['US']  tt0120815         8.6   1346020.0
# 1                            ['US']  tt0075314         8.3    795222.0
# 927                    ['US', 'GB']  tt2084970         8.0    748654.0
# 52                     ['GB', 'US']  tt0093058         8.3    723306.0
# 262                          ['US']  tt0892769         8.1    719717.0
# 264  ['GB', 'US', 'BS', 'CZ', 'DE']  tt0381061         8.0    644336.0
# 282        ['DE', 'ES', 'US', 'FR']  tt0440963         8.0    627009.0

# %%
df_movie_8.genres = df_movie_8.genres.str[1:-1].str.split(',')

# %%
movie_genres = pd.Series(sum([item for item in df_movie_8.genres], [])).str.replace(' ', '').value_counts().to_frame('count')
movie_genres
# Out:
#                  count
# 'drama'             84
# 'comedy'            53
# 'documentation'     48
# 'action'            22
# 'thriller'          22
# 'romance'           18
# 'crime'             18
# 'animation'         13
# 'fantasy'           12
# 'music'             10
# 'sport'             10
# 'history'            9
# 'european'           9
# 'family'             7
# 'scifi'              7
# 'war'                5
# 'horror'             2
# 'reality'            1
# 'western'            1

# %%
movie_genres = movie_genres.reset_index()
movie_genres
# Out:
#               index  count
# 0           'drama'     84
# 1          'comedy'     53
# 2   'documentation'     48
# 3          'action'     22
# 4        'thriller'     22
# 5         'romance'     18
# 6           'crime'     18
# 7       'animation'     13
# 8         'fantasy'     12
# 9           'music'     10
# 10          'sport'     10
# 11        'history'      9
# 12       'european'      9
# 13         'family'      7
# 14          'scifi'      7
# 15            'war'      5
# 16         'horror'      2
# 17        'reality'      1
# 18        'western'      1

# %%
df_movie_8 = df_movie[df_movie['imdb_score'] >= 8]
df_movie_8.loc[ df_movie_8['genres'].str.contains('drama', case=False)].sort_values(by='imdb_votes',ascending=False).head(1)
# Out:
#      index        id         title   type  release_year age_certification  \
# 108    108  tm122434  Forrest Gump  MOVIE          1994             PG-13
#
#      runtime                          genres production_countries    imdb_id  \
# 108      142  ['drama', 'romance', 'comedy']               ['US']  tt0109830
#
#      imdb_score  imdb_votes
# 108         8.8   1994599.0

# %%
df_movie_8.loc[ df_movie_8['genres'].str.contains('crime', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index                   18
# id                      18
# title                   18
# type                    18
# release_year            18
# age_certification       11
# runtime                 18
# genres                  18
# production_countries    18
# imdb_id                 18
# imdb_score              18
# imdb_votes              18
# dtype: int64

# %%
df_movie_8.loc[ df_movie_8['genres'].str.contains('music', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index                   10
# id                      10
# title                   10
# type                    10
# release_year            10
# age_certification        5
# runtime                 10
# genres                  10
# production_countries    10
# imdb_id                 10
# imdb_score              10
# imdb_votes              10
# dtype: int64

# %%
df_movie_8.loc[ df_movie_8['genres'].str.contains('thriller', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index                   22
# id                      22
# title                   22
# type                    22
# release_year            22
# age_certification       12
# runtime                 22
# genres                  22
# production_countries    22
# imdb_id                 22
# imdb_score              22
# imdb_votes              22
# dtype: int64

# %%
df_movie_8.loc[ df_movie_8['genres'].str.contains('comedy', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index                   53
# id                      53
# title                   53
# type                    53
# release_year            53
# age_certification       25
# runtime                 53
# genres                  53
# production_countries    53
# imdb_id                 53
# imdb_score              53
# imdb_votes              53
# dtype: int64

# %%
df_movie_8.loc[ df_movie_8['genres'].str.contains('scifi', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index                   7
# id                      7
# title                   7
# type                    7
# release_year            7
# age_certification       5
# runtime                 7
# genres                  7
# production_countries    7
# imdb_id                 7
# imdb_score              7
# imdb_votes              7
# dtype: int64

# %%
#movie_genres
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=movie_genres['index'],
          width=movie_genres['count'],
          color = 'pink' )
plt.xlabel("Number of Genres")
plt.ylabel("Genres of Movies")
# Out:
# Text(0, 0.5, 'Genres of Movies')

# %%
plt.figure(figsize=(15,5), dpi=150)
ax = plt.gca()
sns.histplot(data=df_movie_8, x='imdb_score', bins=20, alpha=0.6, ax=ax, color = 'pink' )
# Out:
# <AxesSubplot:xlabel='imdb_score', ylabel='Count'>

# %%
# df_movie_8 imdb_votes>=600000
df_movie_top10_vote = df_movie_8[df_movie_8['imdb_votes']>=600000]
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=df_movie_top10_vote['title'],
          width=df_movie_top10_vote['imdb_votes'],
          color = 'pink' )
plt.xlabel("Number of imdb_votes")
plt.ylabel("Title of Movies")
# Out:
# Text(0, 0.5, 'Title of Movies')

# %%
# df_movie_votes_8_lessmean imdb_votes>=35000
df_movie_top10_vote = df_movie_votes_8_lessmean[df_movie_votes_8_lessmean['imdb_votes']>=35000]
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=df_movie_top10_vote['title'],
          width=df_movie_top10_vote['imdb_votes'],
          color = 'pink' )
plt.xlabel("Number of imdb_votes")
plt.ylabel("Title of Movies")
# Out:
# Text(0, 0.5, 'Title of Movies')

# %%
# df_movie_votes_8_moremean imdb_votes>=600000
df_movie_top10_vote = df_movie_votes_8_moremean[df_movie_votes_8_moremean['imdb_votes']>=600000]
plt.figure(figsize=(15,5),dpi=150)
plt.barh( y=df_movie_top10_vote['title'],
          width=df_movie_top10_vote['imdb_votes'],
          color = 'pink' )
plt.xlabel("Number of imdb_votes")
plt.ylabel("Title of Movies")
# Out:
# Text(0, 0.5, 'Title of Movies')

# %% [markdown]
# # country vs title

# %%
#ประเทศไหนผลิตซีรีย์เป็นที่นิยมมากสุด
#df_show_8['production_countries'].nunique()
num = df_show_8.groupby('production_countries')['id'].apply( lambda x: x.nunique() ).to_frame()
num
# Out:
#                        id
# production_countries
# ['AR']                  2
# ['AU']                  9
# ['BE']                  1
# ['BR']                  1
# ['CA']                  8
# ['CL']                  1
# ['CN', 'US']            1
# ['CN']                 14
# ['CO']                  6
# ['DE']                  4
# ['DK']                  2
# ['EG']                  1
# ['ES', 'AR']            1
# ['ES', 'US']            1
# ['ES']                  4
# ['FR']                  4
# ['GB', 'US']            1
# ['GB']                 34
# ['IE']                  1
# ['IL']                  2
# ['IN']                 12
# ['IT']                  1
# ['JP']                 36
# ['KR']                 50
# ['LB']                  1
# ['MX']                  4
# ['PH']                  1
# ['PT']                  1
# ['SA']                  1
# ['SE']                  2
# ['SG']                  1
# ['TH']                  1
# ['TR']                  3
# ['TW']                  5
# ['US', 'CA']            1
# ['US', 'GB']            2
# ['US']                120
# ['ZA']                  1
# []                      9

# %%
#ประเทศไหนผลิตหนังเป็นที่นิยมมากสุด
num2 = df_movie_8.groupby('production_countries')['id'].apply( lambda x: x.nunique() ).to_frame()
num2
# Out:
#                                       id
# production_countries
# ['AR']                                 1
# ['AU']                                 1
# ['BR']                                 2
# ['CA', 'HU', 'MX', 'ES', 'GB', 'US']   1
# ['CA']                                 2
# ['CD', 'GB']                           1
# ['CU', 'US']                           1
# ['DE', 'ES', 'US', 'FR']               1
# ['EG']                                 3
# ['ES']                                 3
# ['FR', 'ES', 'US', 'CA']               1
# ['GB', 'US', 'BS', 'CZ', 'DE']         1
# ['GB', 'US', 'EG']                     1
# ['GB', 'US']                           3
# ['GB']                                 6
# ['HK', 'CN']                           1
# ['ID']                                 1
# ['IN', 'US']                           1
# ['IN']                                54
# ['JP']                                 4
# ['KR']                                 1
# ['KW']                                 1
# ['LB']                                 1
# ['MX']                                 2
# ['PH']                                 3
# ['PS']                                 1
# ['TR']                                 4
# ['TZ']                                 1
# ['UA', 'GB', 'US']                     1
# ['US', 'AT', 'GB']                     1
# ['US', 'DE', 'GB']                     1
# ['US', 'DE']                           1
# ['US', 'GB']                           2
# ['US', 'IT']                           1
# ['US']                                38
# ['ZA', 'GB']                           1
# []                                     6

# %%
#หนังหรือซีรีส์มีความนิยมมากกว่ากัน
df_movie_8['imdb_votes'].describe()
# Out:
# count    1.550000e+02
# mean     1.343318e+05
# std      3.284466e+05
# min      5.000000e+00
# 25%      1.736500e+03
# 50%      9.475000e+03
# 75%      7.314950e+04
# max      2.268288e+06
# Name: imdb_votes, dtype: float64

# %%
df_show_8['imdb_votes'].describe()
#หนังนิยมกว่าดูจากมีน
# Out:
# count    3.500000e+02
# mean     5.767010e+04
# std      1.483926e+05
# min      5.000000e+00
# 25%      1.877000e+03
# 50%      6.153000e+03
# 75%      4.059750e+04
# max      1.727694e+06
# Name: imdb_votes, dtype: float64

# %%
#หนังหรือซีรีส์มีความนิยมมากกว่ากัน
df_show['imdb_votes'].sum()
# Out:
# 32802907.0

# %%
df_movie['imdb_votes'].sum()
# Out:
# 90482789.0

# %% [markdown]
# ## df_credits

# %%
#ความนิยมของนักแสดงหรือผู้กำกับมีผลกับความนิยมหรือไม่
df_credits = pd.read_csv('raw_credits.csv')  
df_credits
# Out:
#        index  person_id         id                    name  \
# 0          0       3748    tm84618          Robert De Niro
# 1          1      14658    tm84618            Jodie Foster
# 2          2       7064    tm84618           Albert Brooks
# 3          3       3739    tm84618           Harvey Keitel
# 4          4      48933    tm84618         Cybill Shepherd
# ...      ...        ...        ...                     ...
# 77208  77208    1347054  tm1098060  Nnenna Rachael Okonkwo
# 77209  77209     157590  tm1098060           Lucien Morgan
# 77210  77210     129059  tm1098060        Magdalena Korpas
# 77211  77211    2050199  tm1098060        Mistura Olusanya
# 77212  77212    2050423  tm1098060              Yemi Amodu
#
#                      character      role
# 0                Travis Bickle     ACTOR
# 1                Iris Steensma     ACTOR
# 2                          Tom     ACTOR
# 3      Matthew 'Sport' Higgins     ACTOR
# 4                        Betsy     ACTOR
# ...                        ...       ...
# 77208                   Afinni     ACTOR
# 77209           Dr. Ian Stones     ACTOR
# 77210                     Jane     ACTOR
# 77211               Nurse Titi     ACTOR
# 77212                      NaN  DIRECTOR
#
# [77213 rows x 6 columns]

# %%
people = df_credits['name'].value_counts().to_frame('count_people')
people.reset_index().head(10)
# Out:
#                    index  count_people
# 0         Shah Rukh Khan            30
# 1            Anupam Kher            25
# 2            Boman Irani            25
# 3    Kareena Kapoor Khan            25
# 4           Paresh Rawal            22
# 5       Takahiro Sakurai            22
# 6    Nawazuddin Siddiqui            21
# 7  Priyanka Chopra Jonas            21
# 8            Raúl Campos            21
# 9              Jan Suter            20

# %%
df_credits['role'].value_counts().to_frame('count_role')
# Out:
#           count_role
# ACTOR          72690
# DIRECTOR        4523

# %% [markdown]
# ## df_merge

# %%
df_merge = pd.merge(df_titles,df_credits,left_on='id',right_on='id')
df_merge
# Out:
#        index_x         id           title   type  release_year  \
# 0            1    tm84618     Taxi Driver  MOVIE          1976
# 1            1    tm84618     Taxi Driver  MOVIE          1976
# 2            1    tm84618     Taxi Driver  MOVIE          1976
# 3            1    tm84618     Taxi Driver  MOVIE          1976
# 4            1    tm84618     Taxi Driver  MOVIE          1976
# ...        ...        ...             ...    ...           ...
# 72845     5804  tm1098060  Shadow Parties  MOVIE          2021
# 72846     5804  tm1098060  Shadow Parties  MOVIE          2021
# 72847     5804  tm1098060  Shadow Parties  MOVIE          2021
# 72848     5804  tm1098060  Shadow Parties  MOVIE          2021
# 72849     5804  tm1098060  Shadow Parties  MOVIE          2021
#
#       age_certification  runtime                  genres production_countries  \
# 0                     R      113      ['crime', 'drama']               ['US']
# 1                     R      113      ['crime', 'drama']               ['US']
# 2                     R      113      ['crime', 'drama']               ['US']
# 3                     R      113      ['crime', 'drama']               ['US']
# 4                     R      113      ['crime', 'drama']               ['US']
# ...                 ...      ...                     ...                  ...
# 72845               NaN      116  ['action', 'thriller']                   []
# 72846               NaN      116  ['action', 'thriller']                   []
# 72847               NaN      116  ['action', 'thriller']                   []
# 72848               NaN      116  ['action', 'thriller']                   []
# 72849               NaN      116  ['action', 'thriller']                   []
#
#        seasons     imdb_id  imdb_score  imdb_votes  index_y  person_id  \
# 0          NaN   tt0075314         8.3    795222.0        0       3748
# 1          NaN   tt0075314         8.3    795222.0        1      14658
# 2          NaN   tt0075314         8.3    795222.0        2       7064
# 3          NaN   tt0075314         8.3    795222.0        3       3739
# 4          NaN   tt0075314         8.3    795222.0        4      48933
# ...        ...         ...         ...         ...      ...        ...
# 72845      NaN  tt10168094         6.2         9.0    77208    1347054
# 72846      NaN  tt10168094         6.2         9.0    77209     157590
# 72847      NaN  tt10168094         6.2         9.0    77210     129059
# 72848      NaN  tt10168094         6.2         9.0    77211    2050199
# 72849      NaN  tt10168094         6.2         9.0    77212    2050423
#
#                          name                character      role
# 0              Robert De Niro            Travis Bickle     ACTOR
# 1                Jodie Foster            Iris Steensma     ACTOR
# 2               Albert Brooks                      Tom     ACTOR
# 3               Harvey Keitel  Matthew 'Sport' Higgins     ACTOR
# 4             Cybill Shepherd                    Betsy     ACTOR
# ...                       ...                      ...       ...
# 72845  Nnenna Rachael Okonkwo                   Afinni     ACTOR
# 72846           Lucien Morgan           Dr. Ian Stones     ACTOR
# 72847        Magdalena Korpas                     Jane     ACTOR
# 72848        Mistura Olusanya               Nurse Titi     ACTOR
# 72849              Yemi Amodu                      NaN  DIRECTOR
#
# [72850 rows x 18 columns]

# %%
df_merge[ df_merge['index_x'] == 5 ]
# Out:
#      index_x       id                         title  type  release_year  \
# 149        5  ts22164  Monty Python's Flying Circus  SHOW          1969
# 150        5  ts22164  Monty Python's Flying Circus  SHOW          1969
# 151        5  ts22164  Monty Python's Flying Circus  SHOW          1969
# 152        5  ts22164  Monty Python's Flying Circus  SHOW          1969
# 153        5  ts22164  Monty Python's Flying Circus  SHOW          1969
#
#     age_certification  runtime                  genres production_countries  \
# 149             TV-14       30  ['comedy', 'european']               ['GB']
# 150             TV-14       30  ['comedy', 'european']               ['GB']
# 151             TV-14       30  ['comedy', 'european']               ['GB']
# 152             TV-14       30  ['comedy', 'european']               ['GB']
# 153             TV-14       30  ['comedy', 'european']               ['GB']
#
#      seasons    imdb_id  imdb_score  imdb_votes  index_y  person_id  \
# 149      4.0  tt0063929         8.8     72895.0      149      11472
# 150      4.0  tt0063929         8.8     72895.0      150      11476
# 151      4.0  tt0063929         8.8     72895.0      151      11475
# 152      4.0  tt0063929         8.8     72895.0      152      11474
# 153      4.0  tt0063929         8.8     72895.0      153      11473
#
#                name             character   role
# 149  Graham Chapman               Various  ACTOR
# 150   Michael Palin  Various / "It's" man  ACTOR
# 151     Terry Jones               Various  ACTOR
# 152       Eric Idle               Various  ACTOR
# 153   Terry Gilliam               Various  ACTOR

# %%
df_merge.isna().sum()
# Out:
# index_x                     0
# id                          0
# title                       0
# type                        0
# release_year                0
# age_certification       28059
# runtime                     0
# genres                      0
# production_countries        0
# seasons                 59995
# imdb_id                     0
# imdb_score                  0
# imdb_votes                  0
# index_y                     0
# person_id                   0
# name                        0
# character                8395
# role                        0
# dtype: int64

# %%
df_merge.loc[ df_merge['role'].str.contains('ACTOR', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index_x                 68768
# id                      68768
# title                   68768
# type                    68768
# release_year            68768
# age_certification       42929
# runtime                 68768
# genres                  68768
# production_countries    68768
# seasons                 12300
# imdb_id                 68768
# imdb_score              68768
# imdb_votes              68768
# index_y                 68768
# person_id               68768
# name                    68768
# character               64455
# role                    68768
# dtype: int64

# %%
df_merge.loc[ df_merge['role'].str.contains('DIRECTOR', case=False)].sort_values(by='imdb_votes',ascending=False).count()
# Out:
# index_x                 4082
# id                      4082
# title                   4082
# type                    4082
# release_year            4082
# age_certification       1862
# runtime                 4082
# genres                  4082
# production_countries    4082
# seasons                  555
# imdb_id                 4082
# imdb_score              4082
# imdb_votes              4082
# index_y                 4082
# person_id               4082
# name                    4082
# character                  0
# role                    4082
# dtype: int64

# %%
#df_show_8['production_countries'].nunique()
num3 = df_merge.groupby('person_id')['name'].apply( lambda x: x.nunique() ).to_frame()
df_merge['name'].unique()
# Out:
# array(['Robert De Niro', 'Jodie Foster', 'Albert Brooks', ...,
#        'Magdalena Korpas', 'Mistura Olusanya', 'Yemi Amodu'], dtype=object)

# %%
df_merge.groupby('name').size().sort_values(ascending=False)
# Out:
# name
# Shah Rukh Khan         29
# Anupam Kher            25
# Boman Irani            25
# Kareena Kapoor Khan    25
# Paresh Rawal           22
#                        ..
# Isabel Ruth             1
# Isabella Barragán       1
# Isabella Castillo       1
# Isabella Crovetti       1
# 허윤무                     1
# Length: 51429, dtype: int64

# %%
df_merge_show_8 = pd.merge(df_show_8,df_credits,left_on='id',right_on='id')
df_merge_show_8
# Out:
#       index_x        id                         title  type  release_year  \
# 0           5   ts22164  Monty Python's Flying Circus  SHOW          1969
# 1           5   ts22164  Monty Python's Flying Circus  SHOW          1969
# 2           5   ts22164  Monty Python's Flying Circus  SHOW          1969
# 3           5   ts22164  Monty Python's Flying Circus  SHOW          1969
# 4           5   ts22164  Monty Python's Flying Circus  SHOW          1969
# ...       ...       ...                           ...   ...           ...
# 2872     5747  ts285422               Newton's Cradle  SHOW          2021
# 2873     5747  ts285422               Newton's Cradle  SHOW          2021
# 2874     5747  ts285422               Newton's Cradle  SHOW          2021
# 2875     5747  ts285422               Newton's Cradle  SHOW          2021
# 2876     5747  ts285422               Newton's Cradle  SHOW          2021
#
#      age_certification  runtime                  genres production_countries  \
# 0                TV-14       30  ['comedy', 'european']               ['GB']
# 1                TV-14       30  ['comedy', 'european']               ['GB']
# 2                TV-14       30  ['comedy', 'european']               ['GB']
# 3                TV-14       30  ['comedy', 'european']               ['GB']
# 4                TV-14       30  ['comedy', 'european']               ['GB']
# ...                ...      ...                     ...                  ...
# 2872             TV-14       41   ['drama', 'thriller']               ['EG']
# 2873             TV-14       41   ['drama', 'thriller']               ['EG']
# 2874             TV-14       41   ['drama', 'thriller']               ['EG']
# 2875             TV-14       41   ['drama', 'thriller']               ['EG']
# 2876             TV-14       41   ['drama', 'thriller']               ['EG']
#
#       seasons     imdb_id  imdb_score  imdb_votes  index_y  person_id  \
# 0         4.0   tt0063929         8.8     72895.0      149      11472
# 1         4.0   tt0063929         8.8     72895.0      150      11476
# 2         4.0   tt0063929         8.8     72895.0      151      11475
# 3         4.0   tt0063929         8.8     72895.0      152      11474
# 4         4.0   tt0063929         8.8     72895.0      153      11473
# ...       ...         ...         ...         ...      ...        ...
# 2872      1.0  tt11703922         8.0      1565.0    76800     141188
# 2873      1.0  tt11703922         8.0      1565.0    76801     309677
# 2874      1.0  tt11703922         8.0      1565.0    76802    1300472
# 2875      1.0  tt11703922         8.0      1565.0    76803     325136
# 2876      1.0  tt11703922         8.0      1565.0    76804     805768
#
#                  name             character      role
# 0      Graham Chapman               Various     ACTOR
# 1       Michael Palin  Various / "It's" man     ACTOR
# 2         Terry Jones               Various     ACTOR
# 3           Eric Idle               Various     ACTOR
# 4       Terry Gilliam               Various     ACTOR
# ...               ...                   ...       ...
# 2872        Mona Zaki                   هنا     ACTOR
# 2873  Mohamed Mamdouh                  حازم     ACTOR
# 2874  Aisha Bin Ahmed                   NaN     ACTOR
# 2875    Mohamed Farag                  مؤنس     ACTOR
# 2876     Tamer Mohsen                   NaN  DIRECTOR
#
# [2877 rows x 18 columns]

# %%
df_merge_show_8.groupby('name').size().sort_values(ascending=False)
# Out:
# name
# Ahn Nae-sang         6
# Lee Jung-eun         4
# Kim Sun-young        4
# Yoshimasa Hosoya     4
# You Chea-myung       4
#                     ..
# Jeffrey Tambor       1
# Jeffrey Walker       1
# Jemima Kirke         1
# Jennifer Barnhart    1
# 허윤무                  1
# Length: 2523, dtype: int64

# %%
df_merge_movie_8 = pd.merge(df_movie_8,df_credits,left_on='id',right_on='id')
df_merge_movie_8
# Out:
#       index_x         id        title   type  release_year age_certification  \
# 0           1    tm84618  Taxi Driver  MOVIE          1976                 R
# 1           1    tm84618  Taxi Driver  MOVIE          1976                 R
# 2           1    tm84618  Taxi Driver  MOVIE          1976                 R
# 3           1    tm84618  Taxi Driver  MOVIE          1976                 R
# 4           1    tm84618  Taxi Driver  MOVIE          1976                 R
# ...       ...        ...          ...    ...           ...               ...
# 2642     5668  tm1024062      Nayattu  MOVIE          2021               NaN
# 2643     5668  tm1024062      Nayattu  MOVIE          2021               NaN
# 2644     5668  tm1024062      Nayattu  MOVIE          2021               NaN
# 2645     5668  tm1024062      Nayattu  MOVIE          2021               NaN
# 2646     5668  tm1024062      Nayattu  MOVIE          2021               NaN
#
#       runtime                          genres production_countries  \
# 0         113              ['crime', 'drama']               ['US']
# 1         113              ['crime', 'drama']               ['US']
# 2         113              ['crime', 'drama']               ['US']
# 3         113              ['crime', 'drama']               ['US']
# 4         113              ['crime', 'drama']               ['US']
# ...       ...                             ...                  ...
# 2642      124  ['drama', 'thriller', 'crime']               ['IN']
# 2643      124  ['drama', 'thriller', 'crime']               ['IN']
# 2644      124  ['drama', 'thriller', 'crime']               ['IN']
# 2645      124  ['drama', 'thriller', 'crime']               ['IN']
# 2646      124  ['drama', 'thriller', 'crime']               ['IN']
#
#          imdb_id  imdb_score  imdb_votes  index_y  person_id             name  \
# 0      tt0075314         8.3    795222.0        0       3748   Robert De Niro
# 1      tt0075314         8.3    795222.0        1      14658     Jodie Foster
# 2      tt0075314         8.3    795222.0        2       7064    Albert Brooks
# 3      tt0075314         8.3    795222.0        3       3739    Harvey Keitel
# 4      tt0075314         8.3    795222.0        4      48933  Cybill Shepherd
# ...          ...         ...         ...      ...        ...              ...
# 2642  tt11604676         8.1      6780.0    76096    2188756  Hakeem Shajahan
# 2643  tt11604676         8.1      6780.0    76097    1907364   Manohariyamama
# 2644  tt11604676         8.1      6780.0    76098    1092348       Sminu Sijo
# 2645  tt11604676         8.1      6780.0    76099     254584       Jaise Jose
# 2646  tt11604676         8.1      6780.0    76100     159884   Martin Prakkat
#
#                     character      role
# 0               Travis Bickle     ACTOR
# 1               Iris Steensma     ACTOR
# 2                         Tom     ACTOR
# 3     Matthew 'Sport' Higgins     ACTOR
# 4                       Betsy     ACTOR
# ...                       ...       ...
# 2642                   Hakkim     ACTOR
# 2643         Praveen's Mother     ACTOR
# 2644           Maniyan's Wife     ACTOR
# 2645        Police Team Coach     ACTOR
# 2646                      NaN  DIRECTOR
#
# [2647 rows x 17 columns]

# %%
df_merge_movie_8.groupby('name').size().sort_values(ascending=False)
# Out:
# name
# Aamir Khan          10
# Terry Jones          6
# Bo Burnham           6
# Nassar               5
# R. Madhavan          4
#                     ..
# Howard Lee           1
# Hrishikesh Joshi     1
# Hrithik Roshan       1
# Hudson West          1
# Laia Alberch         1
# Length: 2465, dtype: int64

# %%
df_merge_movie_8.loc[df_merge_movie_8['name'] == 'Aamir Khan']
# Out:
#       index_x        id                              title   type  \
# 854       368  tm142564                           3 Idiots  MOVIE
# 878       397   tm43399  Lagaan: Once Upon a Time in India  MOVIE
# 914       414   tm83786                Like Stars on Earth  MOVIE
# 926       414   tm83786                Like Stars on Earth  MOVIE
# 929       484   tm61056                     Dil Chahta Hai  MOVIE
# 943       507   tm32885                    Rang De Basanti  MOVIE
# 1119      625  tm368679              Madness in the Desert  MOVIE
# 1646     1033  tm147913                                 PK  MOVIE
# 1862     1375  tm245671                             Dangal  MOVIE
# 2440     4252  tm455981                      Rubaru Roshni  MOVIE
#
#       release_year age_certification  runtime  \
# 854           2009             PG-13      170
# 878           2001                PG      224
# 914           2007                PG      165
# 926           2007                PG      165
# 929           2001                 G      183
# 943           2006             PG-13      157
# 1119          2004               NaN      141
# 1646          2014             PG-13      153
# 1862          2016                PG      161
# 2440          2019               NaN      110
#
#                                                  genres production_countries  \
# 854                                 ['comedy', 'drama']               ['IN']
# 878                       ['drama', 'romance', 'sport']               ['IN']
# 914                                 ['drama', 'family']               ['IN']
# 926                                 ['drama', 'family']               ['IN']
# 929                      ['drama', 'comedy', 'romance']               ['IN']
# 943             ['comedy', 'drama', 'history', 'crime']               ['IN']
# 1119                                  ['documentation']               ['IN']
# 1646  ['comedy', 'drama', 'romance', 'fantasy', 'sci...               ['IN']
# 1862                       ['action', 'drama', 'sport']               ['IN']
# 2440                                  ['documentation']               ['IN']
#
#         imdb_id  imdb_score  imdb_votes  index_y  person_id        name  \
# 854   tt1187043         8.4    385782.0     8866      61013  Aamir Khan
# 878   tt0169102         8.1    111053.0     9601      61013  Aamir Khan
# 914   tt0986264         8.3    188234.0     9948      61013  Aamir Khan
# 926   tt0986264         8.3    188234.0     9960      61013  Aamir Khan
# 929   tt0292490         8.1     71167.0    11112      61013  Aamir Khan
# 943   tt0460895         8.1    118092.0    11477      61013  Aamir Khan
# 1119  tt0417528         8.4       373.0    12914      61013  Aamir Khan
# 1646  tt2338151         8.2    178012.0    19874      61013  Aamir Khan
# 1862  tt5074352         8.4    180247.0    24436      61013  Aamir Khan
# 2440  tt9663460         8.7       584.0    61285      61013  Aamir Khan
#
#                  character      role
# 854                 Rancho     ACTOR
# 878                 Bhuvan     ACTOR
# 914    Ram Shankar Nikumbh     ACTOR
# 926                    NaN  DIRECTOR
# 929                  Akash     ACTOR
# 943      Daljit 'DJ' Singh     ACTOR
# 1119               Himself     ACTOR
# 1646                    PK     ACTOR
# 1862  Mahavir Singh Phogat     ACTOR
# 2440               Himself     ACTOR

# %%
df_show_8['release_year'] = pd.to_datetime(df_show_8['release_year'], format='%Y')

# Group the data by release year and count the number of titles in each year
year_counts = df_show_8.groupby('release_year').size()

# Create a line plot of the title counts over time
plt.figure(figsize=(12,12))
plt.plot(year_counts.index, year_counts.values)
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.title('Content Trends Over Time on Netflix')
plt.show()
# Out:
# <ipython-input-272-26aaa31cf553>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_show_8['release_year'] = pd.to_datetime(df_show_8['release_year'], format='%Y')

# %%
df_show_8.groupby('release_year').size()
# Out:
# release_year
# 1969-01-01     1
# 1972-01-01     1
# 1989-01-01     1
# 1993-01-01     1
# 1995-01-01     1
# 1997-01-01     1
# 1998-01-01     2
# 1999-01-01     1
# 2000-01-01     2
# 2001-01-01     1
# 2002-01-01     4
# 2003-01-01     2
# 2005-01-01     4
# 2006-01-01     7
# 2007-01-01     3
# 2008-01-01     5
# 2009-01-01     3
# 2010-01-01     6
# 2011-01-01     9
# 2012-01-01    10
# 2013-01-01    11
# 2014-01-01    11
# 2015-01-01    31
# 2016-01-01    34
# 2017-01-01    39
# 2018-01-01    51
# 2019-01-01    43
# 2020-01-01    28
# 2021-01-01    28
# 2022-01-01     9
# dtype: int64

# %%
df_movie_8['release_year'] = pd.to_datetime(df_movie_8['release_year'], format='%Y')

# Group the data by release year and count the number of titles in each year
year_counts = df_movie_8.groupby('release_year').size()

# Create a line plot of the title counts over time
plt.figure(figsize=(12,12))
plt.plot(year_counts.index, year_counts.values)
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.title('Content Trends Over Time on Netflix')
plt.show()
# Out:
# <ipython-input-274-f42bdfb034ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie_8['release_year'] = pd.to_datetime(df_movie_8['release_year'], format='%Y')

# %%
df_movie_8.groupby('release_year').size()
# Out:
# release_year
# 1973-01-01     1
# 1975-01-01     1
# 1976-01-01     1
# 1979-01-01     3
# 1982-01-01     1
# 1984-01-01     1
# 1985-01-01     1
# 1986-01-01     1
# 1987-01-01     1
# 1989-01-01     1
# 1993-01-01     1
# 1994-01-01     1
# 1995-01-01     1
# 1997-01-01     1
# 1998-01-01     1
# 1999-01-01     1
# 2001-01-01     4
# 2002-01-01     2
# 2003-01-01     2
# 2004-01-01     5
# 2006-01-01     5
# 2007-01-01     4
# 2008-01-01     2
# 2009-01-01     2
# 2010-01-01     5
# 2011-01-01     5
# 2012-01-01     8
# 2013-01-01    10
# 2014-01-01    11
# 2015-01-01     5
# 2016-01-01     4
# 2017-01-01    10
# 2018-01-01    13
# 2019-01-01    18
# 2020-01-01    12
# 2021-01-01     9
# 2022-01-01     1
# dtype: int64
